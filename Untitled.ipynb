# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
meteo=pd.read_csv(r'00_raw_data\meteo_dekad.csv', sep='\t')

# %%
meteo.head()
# Out:
#    year month  decade       y-m-d  t_mean  t_longterm  precip  snow  \
# 0  2008   Nov       1  2008-Nov-1    3.30         3.4     1.9   NaN
# 1  2008   Nov       2  2008-Nov-2    4.83         1.5    16.7   NaN
# 2  2008   Nov       3  2008-Nov-3    1.31         0.4     7.7   8.0
# 3  2008   Dec       1  2008-Dec-1    2.53        -2.0    38.6   NaN
# 4  2008   Dec       2  2008-Dec-2   -0.21        -2.4     9.3   3.0
#
#    precip_longterm
# 0             15.0
# 1             15.0
# 2             14.0
# 3             13.0
# 4             15.0

# %%
meteo=meteo.fillna(0)

# %%
meteo.head()
# Out:
#    year month  decade       y-m-d  t_mean  t_longterm  precip  snow  \
# 0  2008   Nov       1  2008-Nov-1    3.30         3.4     1.9   0.0
# 1  2008   Nov       2  2008-Nov-2    4.83         1.5    16.7   0.0
# 2  2008   Nov       3  2008-Nov-3    1.31         0.4     7.7   8.0
# 3  2008   Dec       1  2008-Dec-1    2.53        -2.0    38.6   0.0
# 4  2008   Dec       2  2008-Dec-2   -0.21        -2.4     9.3   3.0
#
#    precip_longterm
# 0             15.0
# 1             15.0
# 2             14.0
# 3             13.0
# 4             15.0

# %%
#creating dataframe for plot
dataset = pd.DataFrame({'Name':['Rohit', 'Seema',
                                'Meena', 'Geeta',
                                'Rajat'],
                         
                   'Height': [155,129,138,164,145],
                   'Weight': [60,40,45,55,60]})
 
# creating axes object and defining plot
ax = dataset.plot(kind = 'line', x = 'Name',
                  y = 'Height', color = 'Blue',
                  linewidth = 3)
 
ax2 = dataset.plot(kind = 'line', x = 'Name',
                   y = 'Weight', secondary_y = True,
                   color = 'Red',  linewidth = 3,
                   ax = ax)
 
#title of the plot
plt.title("Student Data")
 
#labeling x and y-axis
ax.set_xlabel('Name', color = 'g')
ax.set_ylabel('Height', color = "b")
ax2.set_ylabel('Weight', color = 'r')
 
#defining display layout
plt.tight_layout()
 
#show plot
plt.show()#creating dataframe for plot
dataset = pd.DataFrame({'Name':['Rohit', 'Seema',
                                'Meena', 'Geeta',
                                'Rajat'],
                         
                   'Height': [155,129,138,164,145],
                   'Weight': [60,40,45,55,60]})
 
# creating axes object and defining plot
ax = dataset.plot(kind = 'line', x = 'Name',
                  y = 'Height', color = 'Blue',
                  linewidth = 3)
 
ax2 = dataset.plot(kind = 'line', x = 'Name',
                   y = 'Weight', secondary_y = True,
                   color = 'Red',  linewidth = 3,
                   ax = ax)
 
#title of the plot
plt.title("Student Data")
 
#labeling x and y-axis
ax.set_xlabel('Name', color = 'g')
ax.set_ylabel('Height', color = "b")
ax2.set_ylabel('Weight', color = 'r')
 
#defining display layout
plt.tight_layout()
 
#show plot
plt.show()

# %%
meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             510 non-null    int64
#  1   month            510 non-null    object
#  2   decade           510 non-null    int64
#  3   y-m-d            510 non-null    object
#  4   t_mean           510 non-null    float64
#  5   t_longterm       510 non-null    float64
#  6   precip           510 non-null    float64
#  7   snow             510 non-null    float64
#  8   precip_longterm  510 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 36.0+ KB

# %%
meteo.head()
# Out:
#    year month  decade       y-m-d  t_mean  t_longterm  precip  snow  \
# 0  2008   Nov       1  2008-Nov-1    3.30         3.4     1.9   0.0
# 1  2008   Nov       2  2008-Nov-2    4.83         1.5    16.7   0.0
# 2  2008   Nov       3  2008-Nov-3    1.31         0.4     7.7   8.0
# 3  2008   Dec       1  2008-Dec-1    2.53        -2.0    38.6   0.0
# 4  2008   Dec       2  2008-Dec-2   -0.21        -2.4     9.3   3.0
#
#    precip_longterm
# 0             15.0
# 1             15.0
# 2             14.0
# 3             13.0
# 4             15.0

# %%
sns.lineplot(x=meteo["y-m-d"], y = meteo["precip"])
# Out:
# <Axes: xlabel='y-m-d', ylabel='precip'>

# %%
meteo["precip"].max()
# Out:
# 130.9

# %%
mazas=meteo.head(20)

# %%
sns.barplot(x=mazas["y-m-d"], y = mazas["precip"])
# Out:
# <Axes: xlabel='y-m-d', ylabel='precip'>

# %%
plt.scatter(mazas["y-m-d"], mazas["precip"])

# %%
meteo["y_m"] = meteo["year"].astype(str) + "-" + meteo["month"].astype(str)

# %%
meteo.columns
# Out:
# Index(['year', 'month', 'decade', 'y-m-d', 't_mean', 't_longterm', 'precip',
#        'snow', 'precip_longterm', 'y_m'],
#       dtype='object')

# %%
meteo.head()
# Out:
#    year month  decade       y-m-d  t_mean  t_longterm  precip  snow  \
# 0  2008   Nov       1  2008-Nov-1    3.30         3.4     1.9   0.0
# 1  2008   Nov       2  2008-Nov-2    4.83         1.5    16.7   0.0
# 2  2008   Nov       3  2008-Nov-3    1.31         0.4     7.7   8.0
# 3  2008   Dec       1  2008-Dec-1    2.53        -2.0    38.6   0.0
# 4  2008   Dec       2  2008-Dec-2   -0.21        -2.4     9.3   3.0
#
#    precip_longterm       y_m
# 0             15.0  2008-Nov
# 1             15.0  2008-Nov
# 2             14.0  2008-Nov
# 3             13.0  2008-Dec
# 4             15.0  2008-Dec

# %%
#plt.figure(figsize=(20, 5))
g = sns.FacetGrid(meteo, col="year")
g.map(sns.lineplot, x = 'y-m-d', y = 'precip')
#sns.lineplot(x=meteo["y_m_d"], y = meteo["precip"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 3
#       1 #plt.figure(figsize=(20, 5))
#       2 g = sns.FacetGrid(meteo, col="year")
# ----> 3 g.map(sns.lineplot, x = 'y-m-d', y = 'precip')
#
# File C:\mano\ANACONDA\Lib\site-packages\seaborn\axisgrid.py:752, in FacetGrid.map(self, func, *args, **kwargs)
#     749         plot_args = [v.values for v in plot_args]
#     751     # Draw the plot
# --> 752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
#     755 self._finalize_grid(args[:2])
#
# File C:\mano\ANACONDA\Lib\site-packages\seaborn\axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
# ...

# %%
# Rename the "y-m-d" column to "y_m_d"
meteo.rename(columns={"y-m-d": "y_m_d"}, inplace=True)

# Create a FacetGrid with line plots
g = sns.FacetGrid(meteo, col="year")
g.map(sns.lineplot, x="y_m_d", y="precip")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 6
#       4 # Create a FacetGrid with line plots
#       5 g = sns.FacetGrid(meteo, col="year")
# ----> 6 g.map(sns.lineplot, x="y_m_d", y="precip")
#
# File C:\mano\ANACONDA\Lib\site-packages\seaborn\axisgrid.py:752, in FacetGrid.map(self, func, *args, **kwargs)
#     749         plot_args = [v.values for v in plot_args]
#     751     # Draw the plot
# --> 752     self._facet_plot(func, ax, plot_args, kwargs)
#     754 # Finalize the annotations and layout
#     755 self._finalize_grid(args[:2])
#
# File C:\mano\ANACONDA\Lib\site-packages\seaborn\axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
# ...

# %%
# Group by 'y_m' and aggregate columns as needed
agg_functions = {
    't_mean': 'mean',
    't_longterm': 'mean',
    'precip': 'sum',
    'precip_longterm': 'sum'
}

metmonth = meteo.groupby('y_m').agg(agg_functions).reset_index()

# Keep 'year', 'month', and 'y_m' columns unchanged
metmonth['year'] = new_data['y_m'].str.split('-').str[0]
metmonth['month'] = new_data['y_m'].str.split('-').str[1]

# Reorder columns if needed
metmonth = new_data[['year', 'month', 'y_m', 't_mean', 't_longterm', 'precip', 'precip_longterm']]

# %%
metmonth.head()
# Out:
#    year month       y_m     t_mean  t_longterm  precip  precip_longterm
# 0  2008   Dec  2008-Dec   0.376364   -2.466667    58.3             44.0
# 1  2008   Nov  2008-Nov   3.146667    1.766667    26.3             44.0
# 2  2009   Apr  2009-Apr   8.830000    6.933333    13.1             33.0
# 3  2009   Aug  2009-Aug  16.820000   17.300000    67.1             62.0
# 4  2009   Dec  2009-Dec  -2.526970   -2.466667    49.9             44.0

# %%
plt.figure(figsize=(20, 5))
sns.barplot(x=metmonth["y_m"], y = metmonth["precip"])
sns.lineplot(x=metmonth["y_m"], y = metmonth["precip_longterm"], marker='*', linestyle="")
# Out:
# <Axes: xlabel='y_m', ylabel='precip'>

# %%
metmonth["year"].nunique()
# Out:
# 15

# %%
# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
plt.plot?

# %%
# Convert the "y-m-d" column to a datetime format
meteo["y_m_d"] = pd.to_datetime(meteo["y-m-d"], format="%Y-%b-%d")

# Create a scatter plot with facetting
g = sns.relplot(data=meteo, x="y_m_d", y="precip", col="year", kind="line",  height=4, aspect=1.5)
